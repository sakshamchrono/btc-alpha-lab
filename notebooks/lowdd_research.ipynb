# %% [markdown]
# # BTC Low-DD Track Research\n\nThis notebook summarizes the low-drawdown strategy study from `research_lowdd.py`.\nFocus: downside risk control, consistency, deployability.

# %%
import json, pathlib\np = pathlib.Path('../results/lowdd_summary.json')\nobj = json.loads(p.read_text())\nobj['meta']

# %%
obj['ranked']

# %%
best = obj['ranked'][0]['strategy']\nobj['metrics_oos'][best]

# %% [markdown]
# ## Deployability notes\n\n- Vol-targeted sizing with leverage cap 1.0\n- Kill-switch around rolling DD and volatility spikes\n- Turnover cap included in objective\n- Confidence limits + failure modes documented in report JSON/MD
