# %% [markdown]
# # Triple-Objective BTC Research

# %%
import json, pathlib
j=json.loads(pathlib.Path("../results/triple_objective_summary.json").read_text())
j["best_strategy"], j["final_metrics"][j["best_strategy"]]

# %% [markdown]
# Best strategy: **weak_ensemble**
